# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('data/prophetData.csv')
df['ds'] = pd.to_datetime(df['ds'])
df.head()
df = df[-800:]
#df['y'] = df['y']*100

# %%
plt.figure(figsize=(15,7))
plt.plot(df['ds'], df['y'])
plt.show();

# %%
validation_fraction = 0.2

validation_size = int(df.shape[0] * validation_fraction)
df_train = df.iloc[:-validation_size]
df_validation = df.iloc[-validation_size:]
print(df_train.shape)
print(df_validation.shape)
# Out:
# (640, 2)
# (160, 2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib
import math
import Chronos

# %%
def make_train_df():
    y_data = pd.date_range('2018-01-01', '2019-01-01').astype(np.int64)/(1e9*60*60)
    y_data = y_data - y_data.min()

    train_df = np.sin(np.arange(1,100))
    train_df = pd.DataFrame(data={"ds": pd.date_range('2018-01-01', '2019-01-01'),
                                  "y" : np.sin(y_data*2*math.pi/365.25)})
    return train_df

# %%
train_df = make_train_df()
train_df
# Out:
#             ds         y
# 0   2018-01-01  0.000000
# 1   2018-01-02  0.401229
# 2   2018-01-03  0.735034
# 3   2018-01-04  0.945320
# 4   2018-01-05  0.996751
# ..         ...       ...
# 361 2018-12-28 -0.983147
# 362 2018-12-29 -0.973892
# 363 2018-12-30 -0.800980
# 364 2018-12-31 -0.493468
# 365 2019-01-01 -0.103031
#
# [366 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(train_df['ds'], train_df['y'])
plt.show()

# %%
importlib.reload(Chronos)
train_df = make_train_df()
my_cr = Chronos.Chronos(G=1000,
                        p_m= 0.3, 
                        r_m = 0.4,
                        yearly_seasonality=1,
                        monthly_seasonality=1)
my_cr = my_cr.fit(train_df)
# Out:
# population initalized
# g: 4000	 train_fitness: 0.01

# %%
result_df = my_cr.predict(train_df)
result_df.head()
# Out:
#           ds         y      yhat
# 0 2018-01-01  0.000000  0.003332
# 1 2018-01-02  0.401229  0.400869
# 2 2018-01-03  0.735034  0.731605
# 3 2018-01-04  0.945320  0.939963
# 4 2018-01-05  0.996751  0.990931

# %%
plt.figure(figsize=(15,5))
plt.plot(result_df['ds'], result_df['y'])
plt.plot(result_df['ds'], result_df['yhat'])
plt.show()
my_cr.get_params()
# Out:
# {'growth::const': 0.003331567385772699,
#  'growth::coef': 5.290977262388558e-07,
#  'yearly::order_1_coef': 0.9907682910460116}
