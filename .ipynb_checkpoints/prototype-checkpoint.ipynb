# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('data/prophetData.csv')
df['ds'] = pd.to_datetime(df['ds'])
df.head()
df = df[-800:]
#df['y'] = df['y']*100

# %%
plt.figure(figsize=(15,7))
plt.plot(df['ds'], df['y'])
plt.show();

# %%
validation_fraction = 0.2

validation_size = int(df.shape[0] * validation_fraction)
df_train = df.iloc[:-validation_size]
df_validation = df.iloc[-validation_size:]
print(df_train.shape)
print(df_validation.shape)
# Out:
# (640, 2)
# (160, 2)

# %%
import importlib
import Chronos

# %%
importlib.reload(Chronos)
my_cr = Chronos.Chronos(G=400,
                        p_m= 0.1, 
                        r_m = 0.1,
                        yearly_seasonality=5,
                        monthly_seasonality=5)

# %%
my_cr = my_cr.fit(df_train)
# Out:
# 0.9065476720444795
# population initalized
# g: 400	 train_fitness: 2.292

# %%
bla = my_cr.best_individual.copy()
bla
# Out:
# array([ 5.05534659e+00,  3.87203638e-04, -1.43590495e-01, -3.97176037e-02,
#         8.83944699e-02,  1.46928649e-02, -4.62452473e-02,  2.11175082e-03,
#         2.98079676e-02,  1.38176666e-01, -5.80910603e-04, -2.16920878e-02,
#        -9.66906030e-03,  2.10365525e-02])

# %%
#my_cr.best_individual[1] = 0.001

# %%
predict_df = df_train.copy()
predict_df = my_cr.predict(predict_df)
predict_df.head()
# Out:
#              ds         y      yhat
# 2105 2013-11-08  8.157657  5.058388
# 2106 2013-11-09  7.829233  5.200873
# 2107 2013-11-10  8.573952  5.087030
# 2108 2013-11-11  9.611329  4.971641
# 2109 2013-11-12  8.923858  5.055350

# %%
predict_df.tail()
# Out:
#              ds         y       yhat
# 2740 2015-08-08  7.007601  11.127159
# 2741 2015-08-09  7.073270  11.102156
# 2742 2015-08-10  7.265430  10.972554
# 2743 2015-08-11  7.602401  11.148528
# 2744 2015-08-12  7.557473  11.351979

# %%
from Chronos import CHRONOS_MSE
CHRONOS_MSE(predict_df['y'], predict_df['yhat'])
# Out:
# 1.8096792873449161

# %%
plt.figure(figsize=(15,7))
plt.scatter(predict_df['ds'], predict_df['y'], c="black")
plt.plot(predict_df['ds'], predict_df['yhat'], c="blue")
plt.show();
