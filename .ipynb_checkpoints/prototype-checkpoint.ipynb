# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('data/prophetData.csv')
df['ds'] = pd.to_datetime(df['ds'])
df.head()
df = df[-200:]
#df['y'] = df['y']*100

# %%
plt.figure(figsize=(15,7))
plt.plot(df['ds'], df['y'])
plt.show();
# Out:
# C:\Users\Boris\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
validation_fraction = 0.2

validation_size = int(df.shape[0] * validation_fraction)
df_train = df.iloc[:-validation_size]
df_validation = df.iloc[-validation_size:]
print(df_train.shape)
print(df_validation.shape)
# Out:
# (160, 2)
# (40, 2)

# %%
import importlib
import Chronos

# %%
importlib.reload(Chronos)
my_cr = Chronos.Chronos(G=400,
                        p_m= 0.1, 
                        r_m = 0.5,
                        yearly_seasonality=5,
                        monthly_seasonality=5)

# %%
my_cr = my_cr.fit(df_train)
# Out:
# 0.7393433622319088
# population initalized
# g: 400	 train_fitness: 0.78

# %%
bla = my_cr.best_individual.copy()
bla
# Out:
# array([ 6.32576821e+00,  8.28796842e-04, -1.10661064e-01, -1.06532951e-01,
#         5.69255298e-02, -4.80909099e-03, -8.53367084e-02, -2.72874716e-02])

# %%
#my_cr.best_individual[1] = 0.001

# %%
predict_df = df_train.copy()
predict_df = my_cr.predict(predict_df)
predict_df.head()
# Out:
#              ds         y      yhat
# 2705 2015-07-04  6.473891  6.319854
# 2706 2015-07-05  6.499787  6.217551
# 2707 2015-07-06  6.859615  6.352379
# 2708 2015-07-07  6.881411  6.410235
# 2709 2015-07-08  6.997596  6.359743

# %%
predict_df.tail()
# Out:
#              ds         y      yhat
# 2860 2015-12-07  8.496786  9.362899
# 2861 2015-12-08  7.981050  9.482355
# 2862 2015-12-09  7.777793  9.470590
# 2863 2015-12-10  8.260234  9.445998
# 2864 2015-12-11  7.866339  9.480386

# %%
from Chronos import CHRONOS_MSE
CHRONOS_MSE(predict_df['y'], predict_df['yhat'])
# Out:
# 0.6077743495475912

# %%
plt.figure(figsize=(15,7))
plt.plot(predict_df['ds'], predict_df['y'])
plt.plot(predict_df['ds'], predict_df['yhat'])
plt.show();
