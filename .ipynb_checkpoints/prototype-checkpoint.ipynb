# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('data/prophetData.csv')
df['ds'] = pd.to_datetime(df['ds'])
df.head()
df = df[-200:]

# %%
plt.figure(figsize=(15,7))
plt.plot(df['ds'], df['y'])
plt.show();

# %%
validation_fraction = 0.2

validation_size = int(df.shape[0] * validation_fraction)
df_train = df.iloc[:-validation_size]
df_validation = df.iloc[-validation_size:]
print(df_train.shape)
print(df_validation.shape)
# Out:
# (160, 2)
# (40, 2)

# %%
import importlib
import Chronos

# %%
importlib.reload(Chronos)
my_cr = Chronos.Chronos(G=400,
                        p_m= 0.01, 
                        r_m = 1.0)

# %%
my_cr = my_cr.fit(df_train)
# Out:
# population initalized
# g: 146	 	 train_fitness: 2.5529834800223616
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-265-c1ba989272ad> in <module>
# ----> 1 my_cr = my_cr.fit(df_train)
#
# ~\Documents\Chronos\Chronos.py in fit(self, tsdf)
#     171             for population_index in range(self.MU):
#     172                 selected_index = self.perform_tournament_selection(self.offspring,
# --> 173                                                                    self.offspring_fitnesses)
#     174                 self.population[population_index, :] = self.offspring[selected_index, :]
#     175
#
# ~\Documents\Chronos\Chronos.py in perform_tournament_selection(self, the_population, population_fitnesses, tournament_size)
#      88
#      89
# ---> 90         winner = selected_fitnesses_indexes[np.argmin(fitnesses)]
#      91         #print(winner)
#      92
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in argmin(a, axis, out)
#    1170
#    1171     """
# -> 1172     return _wrapfunc(a, 'argmin', axis=axis, out=out)
#    1173
#    1174
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      54 def _wrapfunc(obj, method, *args, **kwds):
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#      58     # An AttributeError occurs if the object does not have
#
# KeyboardInterrupt:

# %%
my_cr.best_individual

# %%
train_df = df_train.copy()
train_df['ts'] = train_df['ds'].astype(np.int64)/(1e9*60*60)
min_ts = train_df['ts'].min()
train_df['ts'] = train_df['ts'] - min_ts

# %%
predictions = my_cr.best_individual[0] + (train_df['ts'] * my_cr.best_individual[1])
predictions += my_cr.best_individual[2]* np.sin((train_df['ts']/365.25) + my_cr.best_individual[3])

# %%
predictions.head()

# %%
from Chronos import CHRONOS_MSE
CHRONOS_MSE(train_df['y'], predictions)
# Out:
# 2.961669390059625

# %%
plt.figure(figsize=(15,7))
plt.plot(train_df['ds'], train_df['y'])
plt.plot(train_df['ds'], predictions)
plt.show();
